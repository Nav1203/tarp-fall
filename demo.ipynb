# %%
import utils
display = utils.notebook_init()
# Out:
# YOLOv5  2023-2-15 Python-3.8.2 torch-1.13.1+cpu CPU
# Setup complete  (8 CPUs, 15.8 GB RAM, 48.7/488.3 GB disk)

# %%
# !unzip -q ../fall_dataset.zip -d../

# %%
from IPython.display import Image
Image(filename='D:\\project\\tarp_proj\\runs\\train\exp\\val_batch0_labels.jpg',width=1000)

# %%
python detect.py --weights D://project//tarp_proj//runs//train//exp//weights//best.pt --img 640 --conf 0.25 --source D:\\project\\tarp_proj\\Input_videos\\fall_detection_1.mp4
